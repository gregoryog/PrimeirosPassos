# %% [markdown]
# <a href="https://colab.research.google.com/github/gregoryog/PrimeirosPassos/blob/main/Livrariapassos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Classe para representar um livro

class Livro:

    def __init__(self, titulo, autor, ano_publicacao):

        self.titulo = titulo

        self.autor = autor

        self.ano_publicacao = ano_publicacao



    def __str__(self):

        return f"{self.titulo} por {self.autor}, Publicado em {self.ano_publicacao}"

# %%
# Criar uma lista de livros

biblioteca = []

# Função para adicionar um livro à biblioteca

def adicionar_livro(titulo, autor, ano_publicacao):

    novo_livro = Livro(titulo, autor, ano_publicacao)

    biblioteca.append(novo_livro)

    print(f"{titulo}' foi adicionado à biblioteca.")

# Função para listar todos os livros na biblioteca

def listar_livros():

    print()

    for livro in biblioteca:

        print(livro)

# %%
# Adicionar alguns livros à biblioteca

adicionar_livro("Harry Potter e a Pedra Filosofal", "JK Rowling", 1997)

adicionar_livro("O Arquipélago", "Érico Veríssimo", 1961)

adicionar_livro("Sitio do PicaPau Amarelo", "Monteiro Lobato", 1920)

adicionar_livro("A Guerra no Bom Fim", "Moacyr Scliar", 1972)

adicionar_livro("Como Treinar seu Dragão", "Cressida Cowell", 2003)
# Out:
# Harry Potter e a Pedra Filosofal' foi adicionado à biblioteca.
# O Arquipélago' foi adicionado à biblioteca.
# Sitio do PicaPau Amarelo' foi adicionado à biblioteca.
# A Guerra no Bom Fim' foi adicionado à biblioteca.
# Como Treinar seu Dragão' foi adicionado à biblioteca.

# %%
# Listar todos os livros na biblioteca

listar_livros()



# The following lines caused a NameError because 'anos' was not defined at this point.

# We have addressed this in a separate step by extracting the years first.

# anos = list(set(anos))# Remove duplicatas dos anos

# anos.sort()
# Out:
# Harry Potter e a Pedra Filosofal por JK Rowling, Publicado em 1997
# O Arquipélago por Érico Veríssimo, Publicado em 1961
# Sitio do PicaPau Amarelo por Monteiro Lobato, Publicado em 1920
# A Guerra no Bom Fim por Moacyr Scliar, Publicado em 1972
# Como Treinar seu Dragão por Cressida Cowell, Publicado em 2003

# %%
# Prepare data for plotting

anos_ordenados = sorted(contagem_por_ano.keys())

contagens_ordenadas = [contagem_por_ano[ano] for ano in anos_ordenados]



# Criar um gráfico de linha

plt.figure(figsize=(10, 6)) # Optional: Adjust figure size

plt.plot(anos_ordenados, contagens_ordenadas, marker='o', linestyle='-')

plt.xlabel('Ano de Publicação')

plt.ylabel('Número de Livros')

plt.title('Distribuição de Livros na Biblioteca por Ano de Publicação')

plt.xticks(anos_ordenados) # Ensure all years are shown on x-axis
# Out:
# ([<matplotlib.axis.XTick at 0x79e584da8fb0>,
# ...
#  [Text(1920, 0, '1920'),
#   Text(1961, 0, '1961'),
#   Text(1972, 0, '1972'),
#   Text(1997, 0, '1997'),
#   Text(2003, 0, '2003')])

# %%
# Import matplotlib

import matplotlib.pyplot as plt

# %%
# Extract publication years

anos = [livro.ano_publicacao for livro in biblioteca]

# %%
# Contagem de livros por ano

contagem_por_ano = [anos.count(ano) for ano in anos]

# %%
# Criar um gráfico de linha

plt.plot(anos, contagem_por_ano, marker='o', linestyle='-')

plt.xlabel('Ano de Publicação')

plt.ylabel('Número de Livros')

plt.title('Distribuição de Livros na Biblioteca por Ano de Publicação')
# Out:
# Text(0.5, 1.0, 'Distribuição de Livros na Biblioteca por Ano de Publicação')

# %%
# Adicionar rótulos aos pontos de dados

for i, valor in enumerate(contagens_ordenadas):

    plt.text(anos_ordenados[i], valor, str(valor), ha='center', va='bottom')



plt.grid(True)



plt.show()

# %% [markdown]
# # Task
# Explain the error in the selected code, fix it, and plot the number of books published per year.

# %% [markdown]
# ## Extract publication years
#
# ### Subtask:
# Get the `ano_publicacao` for each `Livro` object in the `biblioteca` list.

# %% [markdown]
# **Reasoning**:
# Initialize an empty list `anos` and then iterate through the `biblioteca` list to extract the `ano_publicacao` for each book.
